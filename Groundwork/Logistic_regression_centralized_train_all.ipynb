# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# This document is based on `logistic_regression_centralized_one_complication`, where a centralized logistic regression model is trained for a single complication.
#
# To evaluate all four complications, we add a wrapper function that runs the training and evaluation pipeline once for each complication:
#
# - Alveolar Osteitis
# - Secondary Infection
# - Nerve Dysesthesia
# - Bleeding
#
# For each complication, a separate logistic regression model is trained on the full centralized dataset.
# The wrapper stores the final F1-score for each complication. To obtain a single performance measure, we compute the average of the four macro F1-scores:
#
# $$
# F1_{\text{overall}}
# =
# \frac{1}{4}
# \sum_{c=1}^{4}
# F1_c,
# $$

# %% [markdown]
# ## Data

# %%
path_train = r"C:\Users\oskar\OneDrive\Desktop\4 Semester\Dataproject\Federated-dental-risk-vol2\federated-dental-risk-prediction\data\raw\synthetic_dataset_A_non-iid.csv"
path_test = r"C:\Users\oskar\OneDrive\Desktop\4 Semester\Dataproject\Federated-dental-risk-vol2\federated-dental-risk-prediction\data\processed\A\global_test_set_non-iid.csv"

df = pd.read_csv(path_train)
test_data = pd.read_csv(path_test)

variables = df.columns[2:27].tolist()

complications = [
    "Risk_AlveolarOsteitis",
    "Risk_SecondaryInfection",
    "Risk_NerveDysesthesia",
    "Risk_Bleeding"
]

client_col = "Client"

scaler = StandardScaler()

train_design = pd.DataFrame(
    scaler.fit_transform(df[variables]),
    columns=variables,
    index=df.index
)

test_design = pd.DataFrame(
    scaler.transform(test_data[variables]),
    columns=variables,
    index=test_data.index
)

for complication in complications:
    category_col = complication.replace("Risk_", "Risk_Category_", 1)

    train_design[complication] = df[complication].values
    train_design[category_col] = df[category_col].values

    test_design[complication] = test_data[complication].values
    test_design[category_col] = test_data[category_col].values

train_design[client_col] = df[client_col].values

# %% [markdown]
# ## Functions

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))


def assign_tertiles(y_hat):
    q1 = np.quantile(y_hat, 1/3)
    q2 = np.quantile(y_hat, 2/3)

    groups = np.where(
        y_hat <= q1, 0,
        np.where(y_hat <= q2, 1, 2)
    )

    return groups, q1, q2


def metrics_for_one_complication(y_true, y_pred):
    results = {}

    for cls in [0, 1, 2]:
        tp = np.sum((y_true == cls) & (y_pred == cls))
        fp = np.sum((y_true != cls) & (y_pred == cls))
        fn = np.sum((y_true == cls) & (y_pred != cls))

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0

        f1 = (
            2 * precision * recall / (precision + recall)
            if (precision + recall) > 0 else 0.0
        )

        results[cls] = {
            "TP": tp,
            "FP": fp,
            "FN": fn,
            "precision": precision,
            "recall": recall,
            "f1": f1
        }

    macro_f1 = np.mean([results[cls]["f1"] for cls in [0, 1, 2]])

    return {
        "per_class": results,
        "macro_f1": macro_f1
    }


def centralized_logistic_regression_binary(
    train_df,
    test_df,
    variables,
    target_col,
    category_col,
    epochs=50,
    lr=0.001,
    random_state=42
):
    X_train = train_df[variables].to_numpy(dtype=float)
    y_train = train_df[target_col].to_numpy(dtype=int)

    X_test = test_df[variables].to_numpy(dtype=float)
    y_true_group = test_df[category_col].to_numpy(dtype=int)

    model = SGDClassifier(
        loss="log_loss",
        penalty=None,
        learning_rate="constant",
        eta0=lr,
        max_iter=1,
        tol=None,
        warm_start=True,
        random_state=random_state
    )

    history = []

    # Initialisering
    model.partial_fit(
        X_train[:1],
        y_train[:1],
        classes=np.array([0, 1])
    )

    for epoch in range(epochs):

        old_coef = model.coef_.copy()
        old_intercept = model.intercept_.copy()

        # Én epoch på samlet data
        model.partial_fit(X_train, y_train)

        coef_change = np.linalg.norm(model.coef_ - old_coef)
        intercept_change = np.linalg.norm(model.intercept_ - old_intercept)

        logits = X_test @ model.coef_.T + model.intercept_
        probs = sigmoid(logits).ravel()

        y_pred_group, q1, q2 = assign_tertiles(probs)

        metrics = metrics_for_one_complication(y_true_group, y_pred_group)
        macro_f1 = metrics["macro_f1"]

        history.append({
            "epoch": epoch + 1,
            "macro_f1": macro_f1,
            "q1": q1,
            "q2": q2,
            "coef_change": coef_change,
            "intercept_change": intercept_change
        })

        print(
            f"Epoch {epoch+1:03d} | Macro F1 = {macro_f1:.4f} | "
            f"coef_change = {coef_change:.6f} | "
            f"intercept_change = {intercept_change:.6f}"
        )

    return model.intercept_, model.coef_, pd.DataFrame(history)

def run_all_centralized_logistic_complications(
    train_df,
    test_df,
    variables,
    complications,
    epochs=50,
    lr=0.001,
    random_state=42
):
    results = {}
    models = {}
    macro_f1s = []

    for complication in complications:
        category_col = complication.replace("Risk_", "Risk_Category_", 1)

        print("\n==============================")
        print(f"Running {complication}")
        print("==============================")

        intercept, coef, history = centralized_logistic_regression_binary(
            train_df=train_df,
            test_df=test_df,
            variables=variables,
            target_col=complication,
            category_col=category_col,
            epochs=epochs,
            lr=lr,
            random_state=random_state
        )

        final_f1 = history["macro_f1"].iloc[-1]

        results[complication] = {
            "history": history,
            "final_macro_f1": final_f1
        }

        models[complication] = {
            "intercept": intercept,
            "coef": coef
        }

        macro_f1s.append(final_f1)

    overall_macro_f1 = np.mean(macro_f1s)

    return {
        "models": models,
        "results": results,
        "overall_macro_f1": overall_macro_f1
    }

# %% [markdown]
# ## Traning

# %%
complications = [
    "Risk_AlveolarOsteitis",
    "Risk_SecondaryInfection",
    "Risk_NerveDysesthesia",
    "Risk_Bleeding"
]

centralized_logistic_output = run_all_centralized_logistic_complications(
    train_df=train_design,
    test_df=test_design,
    variables=variables,
    complications=complications,
    epochs=50,
    lr=0.001,
    random_state=42
)

print("\n==============================")
print(f"CENTRALIZED LOGISTIC FINAL F1 = {centralized_logistic_output['overall_macro_f1']:.3f}")
print("==============================")
# Out:
# ==============================
# Running Risk_AlveolarOsteitis
# ==============================
# Epoch 001 | Macro F1 = 0.6666 | coef_change = 0.595054 | intercept_change = 2.407575
# Epoch 002 | Macro F1 = 0.6682 | coef_change = 0.086502 | intercept_change = 0.087112
# Epoch 003 | Macro F1 = 0.6696 | coef_change = 0.015400 | intercept_change = 0.013357
# Epoch 004 | Macro F1 = 0.6696 | coef_change = 0.002844 | intercept_change = 0.002367
# Epoch 005 | Macro F1 = 0.6696 | coef_change = 0.000526 | intercept_change = 0.000433
# Epoch 006 | Macro F1 = 0.6696 | coef_change = 0.000097 | intercept_change = 0.000080
# Epoch 007 | Macro F1 = 0.6696 | coef_change = 0.000018 | intercept_change = 0.000015
# Epoch 008 | Macro F1 = 0.6696 | coef_change = 0.000003 | intercept_change = 0.000003
# Epoch 009 | Macro F1 = 0.6696 | coef_change = 0.000001 | intercept_change = 0.000001
# Epoch 010 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 011 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 012 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 013 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 014 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 015 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 016 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 017 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 018 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 019 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 020 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 021 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 022 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 023 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 024 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 025 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 026 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 027 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 028 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 029 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 030 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 031 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 032 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 033 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 034 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 035 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 036 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 037 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 038 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 039 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 040 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 041 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 042 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 043 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 044 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 045 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 046 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 047 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 048 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 049 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 050 | Macro F1 = 0.6696 | coef_change = 0.000000 | intercept_change = 0.000000
#
# ==============================
# Running Risk_SecondaryInfection
# ==============================
# Epoch 001 | Macro F1 = 0.6708 | coef_change = 0.570792 | intercept_change = 2.885425
# Epoch 002 | Macro F1 = 0.6781 | coef_change = 0.158657 | intercept_change = 0.206785
# Epoch 003 | Macro F1 = 0.6834 | coef_change = 0.051776 | intercept_change = 0.057656
# Epoch 004 | Macro F1 = 0.6828 | coef_change = 0.018218 | intercept_change = 0.019152
# Epoch 005 | Macro F1 = 0.6824 | coef_change = 0.006552 | intercept_change = 0.006707
# Epoch 006 | Macro F1 = 0.6831 | coef_change = 0.002369 | intercept_change = 0.002396
# Epoch 007 | Macro F1 = 0.6831 | coef_change = 0.000857 | intercept_change = 0.000862
# Epoch 008 | Macro F1 = 0.6824 | coef_change = 0.000310 | intercept_change = 0.000311
# Epoch 009 | Macro F1 = 0.6824 | coef_change = 0.000112 | intercept_change = 0.000113
# Epoch 010 | Macro F1 = 0.6824 | coef_change = 0.000041 | intercept_change = 0.000041
# Epoch 011 | Macro F1 = 0.6824 | coef_change = 0.000015 | intercept_change = 0.000015
# Epoch 012 | Macro F1 = 0.6824 | coef_change = 0.000005 | intercept_change = 0.000005
# Epoch 013 | Macro F1 = 0.6824 | coef_change = 0.000002 | intercept_change = 0.000002
# Epoch 014 | Macro F1 = 0.6824 | coef_change = 0.000001 | intercept_change = 0.000001
# Epoch 015 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 016 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 017 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 018 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 019 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 020 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 021 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 022 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 023 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 024 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 025 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 026 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 027 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 028 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 029 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 030 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 031 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 032 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 033 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 034 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 035 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 036 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 037 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 038 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 039 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 040 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 041 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 042 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 043 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 044 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 045 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 046 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 047 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 048 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 049 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
# Epoch 050 | Macro F1 = 0.6824 | coef_change = 0.000000 | intercept_change = 0.000000
#
# ==============================
# Running Risk_NerveDysesthesia
# ==============================
# Epoch 001 | Macro F1 = 0.6823 | coef_change = 0.203476 | intercept_change = 3.606441
# Epoch 002 | Macro F1 = 0.6977 | coef_change = 0.166967 | intercept_change = 0.566493
# Epoch 003 | Macro F1 = 0.7070 | coef_change = 0.145374 | intercept_change = 0.285627
# Epoch 004 | Macro F1 = 0.7120 | coef_change = 0.124386 | intercept_change = 0.181893
# Epoch 005 | Macro F1 = 0.7143 | coef_change = 0.105656 | intercept_change = 0.131020
# Epoch 006 | Macro F1 = 0.7156 | coef_change = 0.089815 | intercept_change = 0.101900
# Epoch 007 | Macro F1 = 0.7216 | coef_change = 0.076860 | intercept_change = 0.083268
# Epoch 008 | Macro F1 = 0.7209 | coef_change = 0.066442 | intercept_change = 0.070276
# Epoch 009 | Macro F1 = 0.7216 | coef_change = 0.058099 | intercept_change = 0.060613
# Epoch 010 | Macro F1 = 0.7239 | coef_change = 0.051382 | intercept_change = 0.053087
# Epoch 011 | Macro F1 = 0.7213 | coef_change = 0.045917 | intercept_change = 0.047033
# Epoch 012 | Macro F1 = 0.7253 | coef_change = 0.041410 | intercept_change = 0.042051
# Epoch 013 | Macro F1 = 0.7246 | coef_change = 0.037640 | intercept_change = 0.037881
# Epoch 014 | Macro F1 = 0.7259 | coef_change = 0.034444 | intercept_change = 0.034347
# Epoch 015 | Macro F1 = 0.7266 | coef_change = 0.031700 | intercept_change = 0.031318
# Epoch 016 | Macro F1 = 0.7272 | coef_change = 0.029319 | intercept_change = 0.028701
# Epoch 017 | Macro F1 = 0.7263 | coef_change = 0.027231 | intercept_change = 0.026420
# Epoch 018 | Macro F1 = 0.7249 | coef_change = 0.025385 | intercept_change = 0.024420
# Epoch 019 | Macro F1 = 0.7249 | coef_change = 0.023741 | intercept_change = 0.022654
# Epoch 020 | Macro F1 = 0.7269 | coef_change = 0.022266 | intercept_change = 0.021086
# Epoch 021 | Macro F1 = 0.7266 | coef_change = 0.020937 | intercept_change = 0.019685
# Epoch 022 | Macro F1 = 0.7273 | coef_change = 0.019731 | intercept_change = 0.018429
# Epoch 023 | Macro F1 = 0.7279 | coef_change = 0.018633 | intercept_change = 0.017297
# Epoch 024 | Macro F1 = 0.7286 | coef_change = 0.017630 | intercept_change = 0.016272
# Epoch 025 | Macro F1 = 0.7286 | coef_change = 0.016709 | intercept_change = 0.015340
# Epoch 026 | Macro F1 = 0.7286 | coef_change = 0.015860 | intercept_change = 0.014490
# Epoch 027 | Macro F1 = 0.7286 | coef_change = 0.015077 | intercept_change = 0.013713
# Epoch 028 | Macro F1 = 0.7273 | coef_change = 0.014352 | intercept_change = 0.012998
# Epoch 029 | Macro F1 = 0.7273 | coef_change = 0.013678 | intercept_change = 0.012340
# Epoch 030 | Macro F1 = 0.7273 | coef_change = 0.013051 | intercept_change = 0.011733
# Epoch 031 | Macro F1 = 0.7273 | coef_change = 0.012466 | intercept_change = 0.011170
# Epoch 032 | Macro F1 = 0.7273 | coef_change = 0.011919 | intercept_change = 0.010648
# Epoch 033 | Macro F1 = 0.7266 | coef_change = 0.011407 | intercept_change = 0.010161
# Epoch 034 | Macro F1 = 0.7266 | coef_change = 0.010927 | intercept_change = 0.009708
# Epoch 035 | Macro F1 = 0.7266 | coef_change = 0.010476 | intercept_change = 0.009284
# Epoch 036 | Macro F1 = 0.7259 | coef_change = 0.010051 | intercept_change = 0.008888
# Epoch 037 | Macro F1 = 0.7266 | coef_change = 0.009651 | intercept_change = 0.008516
# Epoch 038 | Macro F1 = 0.7266 | coef_change = 0.009273 | intercept_change = 0.008166
# Epoch 039 | Macro F1 = 0.7266 | coef_change = 0.008916 | intercept_change = 0.007837
# Epoch 040 | Macro F1 = 0.7266 | coef_change = 0.008578 | intercept_change = 0.007527
# Epoch 041 | Macro F1 = 0.7266 | coef_change = 0.008258 | intercept_change = 0.007234
# Epoch 042 | Macro F1 = 0.7266 | coef_change = 0.007955 | intercept_change = 0.006957
# Epoch 043 | Macro F1 = 0.7266 | coef_change = 0.007666 | intercept_change = 0.006696
# Epoch 044 | Macro F1 = 0.7266 | coef_change = 0.007392 | intercept_change = 0.006447
# Epoch 045 | Macro F1 = 0.7266 | coef_change = 0.007131 | intercept_change = 0.006212
# Epoch 046 | Macro F1 = 0.7266 | coef_change = 0.006883 | intercept_change = 0.005988
# Epoch 047 | Macro F1 = 0.7266 | coef_change = 0.006646 | intercept_change = 0.005776
# Epoch 048 | Macro F1 = 0.7266 | coef_change = 0.006421 | intercept_change = 0.005574
# Epoch 049 | Macro F1 = 0.7266 | coef_change = 0.006205 | intercept_change = 0.005381
# Epoch 050 | Macro F1 = 0.7266 | coef_change = 0.005999 | intercept_change = 0.005197
#
# ==============================
# Running Risk_Bleeding
# ==============================
# Epoch 001 | Macro F1 = 0.5309 | coef_change = 0.120559 | intercept_change = 3.610320
# Epoch 002 | Macro F1 = 0.5304 | coef_change = 0.096653 | intercept_change = 0.562183
# Epoch 003 | Macro F1 = 0.5302 | coef_change = 0.082549 | intercept_change = 0.274533
# Epoch 004 | Macro F1 = 0.5315 | coef_change = 0.069136 | intercept_change = 0.165148
# Epoch 005 | Macro F1 = 0.5289 | coef_change = 0.057228 | intercept_change = 0.110062
# Epoch 006 | Macro F1 = 0.5275 | coef_change = 0.047065 | intercept_change = 0.078162
# Epoch 007 | Macro F1 = 0.5248 | coef_change = 0.038617 | intercept_change = 0.057969
# Epoch 008 | Macro F1 = 0.5263 | coef_change = 0.031713 | intercept_change = 0.044340
# Epoch 009 | Macro F1 = 0.5271 | coef_change = 0.026129 | intercept_change = 0.034681
# Epoch 010 | Macro F1 = 0.5263 | coef_change = 0.021635 | intercept_change = 0.027575
# Epoch 011 | Macro F1 = 0.5259 | coef_change = 0.018025 | intercept_change = 0.022194
# Epoch 012 | Macro F1 = 0.5260 | coef_change = 0.015122 | intercept_change = 0.018029
# Epoch 013 | Macro F1 = 0.5254 | coef_change = 0.012783 | intercept_change = 0.014751
# Epoch 014 | Macro F1 = 0.5260 | coef_change = 0.010893 | intercept_change = 0.012138
# Epoch 015 | Macro F1 = 0.5270 | coef_change = 0.009361 | intercept_change = 0.010035
# Epoch 016 | Macro F1 = 0.5269 | coef_change = 0.008116 | intercept_change = 0.008328
# Epoch 017 | Macro F1 = 0.5269 | coef_change = 0.007102 | intercept_change = 0.006935
# Epoch 018 | Macro F1 = 0.5266 | coef_change = 0.006273 | intercept_change = 0.005792
# Epoch 019 | Macro F1 = 0.5269 | coef_change = 0.005595 | intercept_change = 0.004851
# Epoch 020 | Macro F1 = 0.5272 | coef_change = 0.005037 | intercept_change = 0.004073
# Epoch 021 | Macro F1 = 0.5276 | coef_change = 0.004576 | intercept_change = 0.003428
# Epoch 022 | Macro F1 = 0.5276 | coef_change = 0.004195 | intercept_change = 0.002893
# Epoch 023 | Macro F1 = 0.5265 | coef_change = 0.003876 | intercept_change = 0.002447
# Epoch 024 | Macro F1 = 0.5265 | coef_change = 0.003608 | intercept_change = 0.002075
# Epoch 025 | Macro F1 = 0.5262 | coef_change = 0.003381 | intercept_change = 0.001764
# Epoch 026 | Macro F1 = 0.5262 | coef_change = 0.003186 | intercept_change = 0.001504
# Epoch 027 | Macro F1 = 0.5269 | coef_change = 0.003018 | intercept_change = 0.001286
# Epoch 028 | Macro F1 = 0.5269 | coef_change = 0.002871 | intercept_change = 0.001103
# Epoch 029 | Macro F1 = 0.5269 | coef_change = 0.002741 | intercept_change = 0.000949
# Epoch 030 | Macro F1 = 0.5276 | coef_change = 0.002624 | intercept_change = 0.000820
# Epoch 031 | Macro F1 = 0.5276 | coef_change = 0.002520 | intercept_change = 0.000711
# Epoch 032 | Macro F1 = 0.5276 | coef_change = 0.002425 | intercept_change = 0.000619
# Epoch 033 | Macro F1 = 0.5276 | coef_change = 0.002338 | intercept_change = 0.000541
# Epoch 034 | Macro F1 = 0.5276 | coef_change = 0.002259 | intercept_change = 0.000476
# Epoch 035 | Macro F1 = 0.5276 | coef_change = 0.002185 | intercept_change = 0.000420
# Epoch 036 | Macro F1 = 0.5282 | coef_change = 0.002116 | intercept_change = 0.000373
# Epoch 037 | Macro F1 = 0.5282 | coef_change = 0.002052 | intercept_change = 0.000333
# Epoch 038 | Macro F1 = 0.5282 | coef_change = 0.001991 | intercept_change = 0.000298
# Epoch 039 | Macro F1 = 0.5282 | coef_change = 0.001935 | intercept_change = 0.000269
# Epoch 040 | Macro F1 = 0.5282 | coef_change = 0.001881 | intercept_change = 0.000244
# Epoch 041 | Macro F1 = 0.5282 | coef_change = 0.001831 | intercept_change = 0.000223
# Epoch 042 | Macro F1 = 0.5282 | coef_change = 0.001783 | intercept_change = 0.000205
# Epoch 043 | Macro F1 = 0.5282 | coef_change = 0.001737 | intercept_change = 0.000189
# Epoch 044 | Macro F1 = 0.5282 | coef_change = 0.001694 | intercept_change = 0.000175
# Epoch 045 | Macro F1 = 0.5282 | coef_change = 0.001653 | intercept_change = 0.000163
# Epoch 046 | Macro F1 = 0.5282 | coef_change = 0.001613 | intercept_change = 0.000153
# Epoch 047 | Macro F1 = 0.5282 | coef_change = 0.001576 | intercept_change = 0.000144
# Epoch 048 | Macro F1 = 0.5282 | coef_change = 0.001540 | intercept_change = 0.000136
# Epoch 049 | Macro F1 = 0.5282 | coef_change = 0.001506 | intercept_change = 0.000129
# Epoch 050 | Macro F1 = 0.5282 | coef_change = 0.001473 | intercept_change = 0.000123
#
# ==============================
# CENTRALIZED LOGISTIC FINAL F1 = 0.652
# ==============================

# %% [markdown]
# ### Individual Metrics

# %%
for complication, res in centralized_logistic_output["results"].items():
    print(f"{complication}: {res['final_macro_f1']:.3f}")
# Out:
# Risk_AlveolarOsteitis: 0.670
# Risk_SecondaryInfection: 0.682
# Risk_NerveDysesthesia: 0.727
# Risk_Bleeding: 0.528

# %% [markdown]
# ### Coefficient Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_logistic_magnitude(coefs, variable_names, title):
    
    coefs = np.asarray(coefs).flatten()

    fig, ax = plt.subplots(figsize=(10, 5))

    magnitudes = np.abs(coefs)

    ax.bar(range(len(coefs)), magnitudes)

    ax.set_xticks(range(len(coefs)))
    ax.set_xticklabels(variable_names, rotation=90)

    ax.set_title(title)
    ax.set_xlabel("Variables")
    ax.set_ylabel("|Coefficient|")

    plt.tight_layout()
    plt.show()

def plot_all_centralized_logistic_complications(models, variables):

    for complication, model_dict in models.items():

        plot_logistic_magnitude(
            model_dict["coef"],
            variables,
            title=f"Centralized Logistic Regression - {complication}"
        )

plot_all_centralized_logistic_complications(
    centralized_logistic_output["models"],
    variables
)
